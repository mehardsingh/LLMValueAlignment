# %%
import pandas as pd
import os

# %%
quesiton2section = {
  "Q1": 1,
  "Q2": 1,
  "Q3": 1,
  "Q4": 1,
  "Q5": 1,
  "Q6": 1,
  "Q18": 1,
  "Q19": 1,
  "Q20": 1,
  "Q21": 1,
  "Q22": 1,
  "Q23": 1,
  "Q24": 1,
  "Q25": 1,
  "Q26": 1,
  "Q27": 1,
  "Q28": 1,
  "Q29": 1,
  "Q30": 1,
  "Q31": 1,
  "Q32": 1,
  "Q33": 1,
  "Q34": 1,
  "Q35": 1,
  "Q36": 1,
  "Q37": 1,
  "Q38": 1,
  "Q39": 1,
  "Q40": 1,
  "Q41": 1,
  "Q42": 1,
  "Q43": 1,
  "Q44": 1,
  "Q45": 1,
  "Q46": 2,
  "Q47": 2,
  "Q48": 2,
  "Q49": 2,
  "Q50": 2,
  "Q51": 2,
  "Q52": 2,
  "Q53": 2,
  "Q54": 2,
  "Q55": 2,
  "Q56": 2,
  "Q56": 2,
  "Q57": 3,
  "Q58": 3,
  "Q59": 3,
  "Q60": 3,
  "Q61": 3,
  "Q62": 3,
  "Q63": 3,
  "Q64": 3,
  "Q65": 3,
  "Q66": 3,
  "Q67": 3,
  "Q68": 3,
  "Q69": 3,
  "Q70": 3,
  "Q71": 3,
  "Q72": 3,
  "Q73": 3,
  "Q74": 3,
  "Q75": 3,
  "Q76": 3,
  "Q77": 3,
  "Q78": 3,
  "Q79": 3,
  "Q80": 3,
  "Q81": 3,
  "Q82": 3,
  "Q83": 3,
  "Q84": 3,
  "Q85": 3,
  "Q86": 3,
  "Q87": 3,
  "Q88": 3,
  "Q89": 3,
  "Q90": 3,
  "Q91": 3,
  "Q92": 3,
  "Q93": 3,
  "Q94": 3,
  "Q95": 3,
  "Q96": 3,
  "Q97": 3,
  "Q98": 3,
  "Q99": 3,
  "Q100": 3,
  "Q101": 3,
  "Q102": 3,
  "Q103": 3,
  "Q104": 3,
  "Q105": 3,
  "Q106": 4,
  "Q107": 4,
  "Q108": 4,
  "Q109": 4,
  "Q110": 4,
  "Q111": 4,
  "Q112": 5,
  "Q113": 5,
  "Q114": 5,
  "Q115": 5,
  "Q116": 5,
  "Q117": 5,
  "Q118": 5,
  "Q119": 5,
  "Q120": 5,
  "Q121": 5,
  "Q121": 6,
  "Q122": 6,
  "Q123": 6,
  "Q124": 6,
  "Q125": 6,
  "Q126": 6,
  "Q127": 6,
  "Q128": 6,
  "Q129": 6,
  "Q130": 6,
  "Q131": 7,
  "Q132": 7,
  "Q133": 7,
  "Q134": 7,
  "Q135": 7,
  "Q136": 7,
  "Q137": 7,
  "Q138": 7,
  "Q139": 7,
  "Q140": 7,
  "Q141": 7,
  "Q142": 7,
  "Q143": 7,
  "Q144": 7,
  "Q145": 7,
  "Q146": 7,
  "Q147": 7,
  "Q148": 7,
  "Q149": 7,
  "Q150": 7,
  "Q151": 7,
  "Q152": 8,
  "Q153": 8,
  "Q154": 8,
  "Q155": 8,
  "Q156": 8,
  "Q157": 8,
  "Q158": 9,
  "Q159": 9,
  "Q160": 9,
  "Q161": 9,
  "Q162": 9,
  "Q163": 9,
  "Q164": 10,
  "Q165": 10,
  "Q166": 10,
  "Q167": 10,
  "Q168": 10,
  "Q169": 10,
  "Q170": 10,
  "Q171": 10,
  "Q172": 10,
  "Q173": 10,
  "Q174": 10,
  "Q175": 10,
  "Q176": 11,
  "Q177": 11,
  "Q178": 11,
  "Q179": 11,
  "Q180": 11,
  "Q181": 11,
  "Q182": 11,
  "Q183": 11,
  "Q184": 11,
  "Q185": 11,
  "Q186": 11,
  "Q187": 11,
  "Q188": 11,
  "Q189": 11,
  "Q190": 11,
  "Q191": 11,
  "Q192": 11,
  "Q193": 11,
  "Q194": 11,
  "Q195": 11,
  "Q196": 11,
  "Q197": 11,
  "Q198": 11,
  "Q199": 12,
  "Q200": 12,
  "Q201": 12,
  "Q202": 12,
  "Q203": 12,
  "Q204": 12,
  "Q205": 12,
  "Q206": 12,
  "Q207": 12,
  "Q208": 12,
  "Q209": 12,
  "Q210": 12,
  "Q211": 12,
  "Q212": 12,
  "Q213": 12,
  "Q214": 12,
  "Q215": 12,
  "Q216": 12,
  "Q217": 12,
  "Q218": 12,
  "Q219": 12,
  "Q220": 12,
  "Q221": 12,
  "Q222": 12,
  "Q224": 12,
  "Q225": 12,
  "Q226": 12,
  "Q227": 12,
  "Q228": 12,
  "Q229": 12,
  "Q230": 12,
  "Q231": 12,
  "Q232": 12,
  "Q233": 12,
  "Q234": 12,
  "Q234A": 12,
  "Q235": 13,
  "Q236": 13,
  "Q237": 13,
  "Q238": 13,
  "Q239": 13,
  "Q240": 13,
  "Q241": 13,
  "Q242": 13,
  "Q243": 13,
  "Q244": 13,
  "Q245": 13,
  "Q246": 13,
  "Q247": 13,
  "Q248": 13,
  "Q249": 13,
  "Q250": 13,
  "Q251": 13,
  "Q252": 13,
  "Q253": 13,
  "Q254": 13,
  "Q255": 13,
  "Q256": 13,
  "Q257": 13,
  "Q258": 13,
  "Q259": 13
}

# %%
dir = "../../results/"
models = os.listdir(dir)
for model in models:
    result_fps = os.listdir(os.path.join(dir, model))
    num_results = len(result_fps)

    for i in range(num_results):
        result_fp = os.path.join(dir, model, f"results_pt{i+1}.csv")
        df = pd.read_csv(result_fp)
        df['Section'] = df['ID'].map(quesiton2section)
        df.to_csv(result_fp)
